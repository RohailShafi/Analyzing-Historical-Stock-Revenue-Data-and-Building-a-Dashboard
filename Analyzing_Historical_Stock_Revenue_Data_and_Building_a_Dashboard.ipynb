# %% [markdown]
# Question 1 - Extracting Tesla Stock Data Using yfinance - 2 Points<br>
# Question 2 - Extracting Tesla Revenue Data Using Webscraping - 1 Points<br>
# Question 3 - Extracting GameStop Stock Data Using yfinance - 2 Points<br>
# Question 4 - Extracting GameStop Revenue Data Using Webscraping - 1 Points<br>
# Question 5 - Tesla Stock and Revenue Dashboard - 2 Points<br>
# Question 6 - GameStop Stock and Revenue Dashboard- 2 Points<br>
# Question 7 - Sharing your Assignment Notebook - 2 Points

# %%
import yfinance as yf

ticker = "TSLA"

tesla_data = yf.download(ticker, start="2023-01-01", end="2023-11-04")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
tesla_data.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-01-03  118.470001  118.800003  104.639999  108.099998  108.099998
# 2023-01-04  109.110001  114.589996  107.519997  113.639999  113.639999
# 2023-01-05  110.510002  111.750000  107.160004  110.339996  110.339996
# 2023-01-06  103.000000  114.389999  101.809998  113.059998  113.059998
# 2023-01-09  118.959999  123.519997  117.110001  119.769997  119.769997
#
#                Volume
# Date
# 2023-01-03  231402800
# 2023-01-04  180389000
# 2023-01-05  157986300
# 2023-01-06  220911100
# 2023-01-09  190284000

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
url = "https://www.macrotrends.net/stocks/charts/TSLA/tesla/revenue"
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# revenue_element = soup.find("xpath", "//span[contains(@class, 'revenue')]")

revenue_data = []
revenue_items = soup.find_all('li')
for item in revenue_items:
    text = item.get_text()
    revenue_data.append(text)

# Print the extracted revenue data
for revenue in revenue_data:
    print(revenue)
revenue_data = pd.DataFrame(revenue_data)
revenue_data.tail()
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# No charts were generated by quickchart

# %%
import yfinance as yf
import pandas as pd

ticker = "TSLA"

gme_data = yf.download(ticker, start="2023-01-01", end="2023-12-31")

gme_data.reset_index(inplace=True)

gme_data.to_csv("tesla_stock_data.csv", index=False)

print(gme_data.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2023-01-03  118.470001  118.800003  104.639999  108.099998  108.099998
# 1 2023-01-04  109.110001  114.589996  107.519997  113.639999  113.639999
# 2 2023-01-05  110.510002  111.750000  107.160004  110.339996  110.339996
# 3 2023-01-06  103.000000  114.389999  101.809998  113.059998  113.059998
# 4 2023-01-09  118.959999  123.519997  117.110001  119.769997  119.769997
#
#       Volume
# 0  231402800
# 1  180389000
# 2  157986300
# 3  220911100
# 4  190284000

# %%
import requests
from bs4 import BeautifulSoup

url = "https://example.com/gme-revenue-page"  # Replace with the actual URL

# Send an HTTP GET request to the webpage
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, 'html.parser')

    # Locate and extract the revenue data
    revenue_element = soup.find('span', class_='revenue')  # Replace with the actual element details

    if revenue_element:
        revenue = revenue_element.get_text()
        print(revenue.tail())
    else:
        print("Revenue data element not found on the page.")
else:
    print("Failed to retrieve the webpage.")
# Out:
# Failed to retrieve the webpage.

# %%
import matplotlib.pyplot as plt
def make_graph(ticker):
    plt.figure(figsize=(12, 6))
    plt.plot(tesla_data['Close'], label=f'{ticker} Closing Price')
    plt.title(f'{ticker} Stock Price')
    plt.xlabel('Date')
    plt.ylabel('Stock Price (USD)')
    plt.legend()
    plt.show()
ticker = "TSLA"
make_graph(ticker)

# %%
ticker_gme = "GME"
make_graph(ticker_gme)
